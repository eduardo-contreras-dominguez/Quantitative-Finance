# %%
import yfinance as yf
import yfinance as yf
import plotly.graph_objs as go
from plotly.subplots import make_subplots
import sys
sys.path.append('/Users/educontreras/PycharmProjects/Quantitative-Finance/AlgoTrading_E_Chang')

from Notebooks import utils
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
data = yf.download(["NVDA","XLF","AMD"], start="2019-01-01")
data = data.loc[:, [element for element in data.columns if "Adj Close" in element]]
print(data.columns)
# Out:
# [*********************100%%**********************]  3 of 3 completed
# MultiIndex([('Adj Close',  'AMD'),
#             ('Adj Close', 'NVDA'),
#             ('Adj Close',  'XLF')],
#            names=['Price', 'Ticker'])

# %%
data.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
data.loc[:, [element for element in data.columns if "Close" in element]]
# Out:
#                  Close
#                   AAPL        AMD
# Date
# 2019-12-31   73.412498  45.860001
# 2020-01-02   75.087502  49.099998
# 2020-01-03   74.357498  48.599998
# 2020-01-06   74.949997  48.389999
# 2020-01-07   74.597504  48.250000
# ...                ...        ...
# 2020-12-24  131.970001  91.809998
# 2020-12-28  136.690002  91.599998
# 2020-12-29  134.869995  90.620003
# 2020-12-30  133.720001  92.290001
# 2020-12-31  132.690002  91.709999
#
# [254 rows x 2 columns]
